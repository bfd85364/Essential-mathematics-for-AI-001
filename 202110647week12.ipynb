# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('/content/Exploratory_Data_Analysis_and_Visualization_(001)_Results.xlsx')
df
# Out:
#     No.  ID number                  Fullname  Assignment 1  Assignment 2  \
# 0     1  202305023         El Jaouhari Nouha           9.0            10
# 1     2  202305024           Pham Mai Phuong           9.5            10
# 2     3  202305030      Taylor Harrison Paul           0.0             0
# 3     4  202305031             Saveleva Olga           8.5            10
# 4     5  202305034         Suyundikova Maiya          10.0            10
# 5     6  202305035  Gupta Divija Sunil Kumar           8.0             7
# 6     7  202305037           Kamalpreet Kaur           7.0             7
# 7     8  202409026            Melcher Yvonne           9.5            10
# 8     9  202409041   Khan Pathan Wasif Umair          10.0            10
# 9    10  202409043           Rhamchaoui Mina          10.0             0
# 10   11  202409052         Osta Sunidhi Jane          10.0            10
#
#     Average Assignment marks(10)  Midterm (20)  Sub-total(30)
# ...

# %%
midscore=df.iloc[:,6]
midscore
# Out:
# 0     16
# 1     20
# 2     14
# 3     19
# 4     14
# 5     12
# 6     15
# 7     20
# 8     17
# 9     15
# 10    20
# Name: Midterm (20), dtype: int64

# %%
name=df.iloc[:,2]
name
# Out:
# 0            El Jaouhari Nouha
# 1              Pham Mai Phuong
# 2         Taylor Harrison Paul
# 3                Saveleva Olga
# 4            Suyundikova Maiya
# 5     Gupta Divija Sunil Kumar
# 6              Kamalpreet Kaur
# 7               Melcher Yvonne
# 8      Khan Pathan Wasif Umair
# 9              Rhamchaoui Mina
# 10           Osta Sunidhi Jane
# Name: Fullname, dtype: object

# %%
marks=df.iloc[:,-1]
marks
# Out:
# 0     25.50
# 1     29.75
# 2     14.00
# 3     28.25
# 4     24.00
# 5     19.50
# 6     22.00
# 7     29.75
# 8     27.00
# 9     20.00
# 10    30.00
# Name: Sub-total(30), dtype: float64

# %%
plt.scatter(midscore,marks)
plt.scatter(19,20)
plt.xlabel("Mid Score")
plt.ylabel("Marks")
plt.title("Mid Score VS Marks")
plt.text(19,20, 'junhyung-kim', bbox={'facecolor':'purple','alpha':0.5})
plt.text(14,14, 'Taylor Harrison Paul')
plt.text(14,24, 'Suyundikova Maiya')
plt.text(12,19.5, 'Gupta Divija Sunil Kumar')
plt.text(15,20,'Rhamchaoui Mina')
plt.text(15,22,'Kamalpreet Kaur')
plt.text(16,25.50,'El Jaouhari Nouha')
plt.text(17,27.00,'Khan Pathan Wasif Umair')
plt.text(19,28, 'Saveleva Olga')
plt.text(20,29, 'Melcher Yvonne', bbox={'facecolor':'red','alpha':0.5})
plt.text(20,30,'Osta Sunidhi Jane', bbox={'facecolor':'blue','alpha':0.5})
plt.show()
